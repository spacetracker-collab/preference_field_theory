# %% [markdown]
# # Preference Field Theory: Alignment Laboratory
# This notebook runs the simulations for **Hamiltonian Dynamics** and **Preference Drift**.

# %%
# !git clone https://github.com/spacetracker-collab/Coding-Solutions.git
# %cd Coding-Solutions
# !git pull origin main

import torch
import matplotlib.pyplot as plt
import numpy as np
from dynamics_engine import simulate_drift_and_alignment

ai_path, goal_path = simulate_drift_and_alignment()
ai_path = np.array(ai_path).squeeze()
goal_path = np.array(goal_path).squeeze()

plt.figure(figsize=(10, 10))
plt.plot(goal_path[:, 0], goal_path[:, 1], 'r--', label='Drifting Human Goal (Target)')
plt.plot(ai_path[:, 0], ai_path[:, 1], 'b-o', label='AI Alignment Path (Hamiltonian)')
plt.title('PFT: Tracking the Moving Cognitive Manifold')
plt.legend()
plt.grid(True)
plt.show()
